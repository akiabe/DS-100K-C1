# %%
import pandas as pd

# %%
customer_master = pd.read_csv("../input/customer_master.csv")
print(customer_master.shape)
customer_master.head(3)
# Out:
# (5000, 9)
#   customer_id customer_name    registration_date customer_name_kana  \
# 0    IK152942        平田 裕次郎  2019-01-01 00:25:33          ひらた ゆうじろう
# 1    TS808488         田村 詩織  2019-01-01 01:13:45            たむら しおり
# 2    AS834628         久野 由樹  2019-01-01 02:00:14             ひさの ゆき
#
#                          email gender  age      birth pref
# 0  hirata_yuujirou@example.com      M   29  1990/6/10  石川県
# 1    tamura_shiori@example.com      F   33  1986/5/20  東京都
# 2      hisano_yuki@example.com      F   63   1956/1/2  茨城県

# %%
transaction_1 = pd.read_csv("../input/transaction_1.csv")
transaction_2 = pd.read_csv("../input/transaction_2.csv")
print(transaction_1.shape)
print(transaction_2.shape)
transaction_1.head(3)
# Out:
# (5000, 4)
# (1786, 4)
#   transaction_id   price         payment_date customer_id
# 0    T0000000113  210000  2019-02-01 01:36:57    PL563502
# 1    T0000000114   50000  2019-02-01 01:37:23    HD678019
# 2    T0000000115  120000  2019-02-01 02:34:19    HD298120

# %%
transaction_all = pd.concat([transaction_1, transaction_2], axis=0)
print(transaction_all.shape)
transaction_all.head(3)
# Out:
# (6786, 4)
#   transaction_id   price         payment_date customer_id
# 0    T0000000113  210000  2019-02-01 01:36:57    PL563502
# 1    T0000000114   50000  2019-02-01 01:37:23    HD678019
# 2    T0000000115  120000  2019-02-01 02:34:19    HD298120

# %%
customer_all = pd.merge(customer_master, transaction_all, on="customer_id", how="left")
print(customer_all.shape)
customer_all.head(3)
# Out:
# (8768, 12)
#   customer_id customer_name    registration_date customer_name_kana  \
# 0    IK152942        平田 裕次郎  2019-01-01 00:25:33          ひらた ゆうじろう
# 1    IK152942        平田 裕次郎  2019-01-01 00:25:33          ひらた ゆうじろう
# 2    IK152942        平田 裕次郎  2019-01-01 00:25:33          ひらた ゆうじろう
#
#                          email gender  age      birth pref transaction_id  \
# 0  hirata_yuujirou@example.com      M   29  1990/6/10  石川県    T0000000381
# 1  hirata_yuujirou@example.com      M   29  1990/6/10  石川県    T0000002879
# 2  hirata_yuujirou@example.com      M   29  1990/6/10  石川県    T0000003093
#
#       price         payment_date
# 0  210000.0  2019-02-08 07:31:14
# 1  120000.0  2019-04-14 23:23:23
# 2  240000.0  2019-04-20 20:02:00

# %%
item_master = pd.read_csv("../input/item_master.csv")
print(item_master.shape)
item_master.head(3)
# Out:
# (5, 3)
#   item_id item_name  item_price
# 0    S001      PC-A       50000
# 1    S002      PC-B       85000
# 2    S003      PC-C      120000

# %%
transaction_detail_1 = pd.read_csv("../input/transaction_detail_1.csv")
transaction_detail_2 = pd.read_csv("../input/transaction_detail_2.csv")
print(transaction_detail_1.shape)
print(transaction_detail_2.shape)
transaction_detail_1.head(3)
# Out:
# (5000, 4)
# (2144, 4)
#    detail_id transaction_id item_id  quantity
# 0          0    T0000000113    S005         1
# 1          1    T0000000114    S001         1
# 2          2    T0000000115    S003         1

# %%
transaction_detail_all = pd.concat([transaction_detail_1, transaction_detail_2], axis=0)
print(transaction_detail_all.shape)
transaction_detail_all.head(3)
# Out:
# (7144, 4)
#    detail_id transaction_id item_id  quantity
# 0          0    T0000000113    S005         1
# 1          1    T0000000114    S001         1
# 2          2    T0000000115    S003         1

# %%
transaction_detail_all = pd.merge(transaction_detail_all, item_master, on="item_id", how="left")
print(transaction_detail_all.shape)
transaction_detail_all.head(3)
# Out:
# (7144, 6)
#    detail_id transaction_id item_id  quantity item_name  item_price
# 0          0    T0000000113    S005         1      PC-E      210000
# 1          1    T0000000114    S001         1      PC-A       50000
# 2          2    T0000000115    S003         1      PC-C      120000

# %%
join_all = pd.merge(transaction_detail_all, customer_all, on="transaction_id", how="left")
print(join_all.shape)
join_all.head(3)
# Out:
# (7144, 17)
#    detail_id transaction_id item_id  quantity item_name  item_price  \
# 0          0    T0000000113    S005         1      PC-E      210000
# 1          1    T0000000114    S001         1      PC-A       50000
# 2          2    T0000000115    S003         1      PC-C      120000
#
#   customer_id customer_name    registration_date customer_name_kana  \
# 0    PL563502         井本 芳正  2019-01-07 14:34:35           いもと よしまさ
# 1    HD678019         三船 六郎  2019-01-27 18:00:11           みふね ろくろう
# 2    HD298120         山根 小雁  2019-01-11 08:16:02            やまね こがん
#
#                          email gender  age       birth pref     price  \
# 0  imoto_yoshimasa@example.com      M   30   1989/7/15  熊本県  210000.0
# 1   mifune_rokurou@example.com      M   73  1945/11/29  京都府   50000.0
# 2     yamane_kogan@example.com      M   42   1977/5/17  茨城県  120000.0
#
#           payment_date
# 0  2019-02-01 01:36:57
# 1  2019-02-01 01:37:23
# 2  2019-02-01 02:34:19

# %%
join_all["price"] = join_all["quantity"] * join_all["item_price"]
print(join_all.shape)
join_all.head(3)
# Out:
# (7144, 17)
#    detail_id transaction_id item_id  quantity item_name  item_price  \
# 0          0    T0000000113    S005         1      PC-E      210000
# 1          1    T0000000114    S001         1      PC-A       50000
# 2          2    T0000000115    S003         1      PC-C      120000
#
#   customer_id customer_name    registration_date customer_name_kana  \
# 0    PL563502         井本 芳正  2019-01-07 14:34:35           いもと よしまさ
# 1    HD678019         三船 六郎  2019-01-27 18:00:11           みふね ろくろう
# 2    HD298120         山根 小雁  2019-01-11 08:16:02            やまね こがん
#
#                          email gender  age       birth pref   price  \
# 0  imoto_yoshimasa@example.com      M   30   1989/7/15  熊本県  210000
# 1   mifune_rokurou@example.com      M   73  1945/11/29  京都府   50000
# 2     yamane_kogan@example.com      M   42   1977/5/17  茨城県  120000
#
#           payment_date
# 0  2019-02-01 01:36:57
# 1  2019-02-01 01:37:23
# 2  2019-02-01 02:34:19

# %%
join_all.isnull().sum()
# Out:
# detail_id             0
# transaction_id        0
# item_id               0
# quantity              0
# item_name             0
# item_price            0
# customer_id           0
# customer_name         0
# registration_date     0
# customer_name_kana    0
# email                 0
# gender                0
# age                   0
# birth                 0
# pref                  0
# price                 0
# payment_date          0
# dtype: int64

# %%
join_all.describe()
# Out:
#          detail_id     quantity     item_price          age          price
# count  7144.000000  7144.000000    7144.000000  7144.000000    7144.000000
# mean   3571.500000     1.199888  121698.628219    50.265677  135937.150056
# std    2062.439494     0.513647   64571.311830    17.190314   68511.453297
# min       0.000000     1.000000   50000.000000    20.000000   50000.000000
# 25%    1785.750000     1.000000   50000.000000    36.000000   85000.000000
# 50%    3571.500000     1.000000  102500.000000    50.000000  120000.000000
# 75%    5357.250000     1.000000  187500.000000    65.000000  210000.000000
# max    7143.000000     4.000000  210000.000000    80.000000  420000.000000

# %%
join_all["payment_date"] = pd.to_datetime(join_all["payment_date"])
join_all["payment_month"] = join_all["payment_date"].dt.strftime("%Y%m")
join_all.head(3)
# Out:
#    detail_id transaction_id item_id  quantity item_name  item_price  \
# 0          0    T0000000113    S005         1      PC-E      210000
# 1          1    T0000000114    S001         1      PC-A       50000
# 2          2    T0000000115    S003         1      PC-C      120000
#
#   customer_id customer_name    registration_date customer_name_kana  \
# 0    PL563502         井本 芳正  2019-01-07 14:34:35           いもと よしまさ
# 1    HD678019         三船 六郎  2019-01-27 18:00:11           みふね ろくろう
# 2    HD298120         山根 小雁  2019-01-11 08:16:02            やまね こがん
#
#                          email gender  age       birth pref   price  \
# 0  imoto_yoshimasa@example.com      M   30   1989/7/15  熊本県  210000
# 1   mifune_rokurou@example.com      M   73  1945/11/29  京都府   50000
# 2     yamane_kogan@example.com      M   42   1977/5/17  茨城県  120000
#
#          payment_date payment_month
# 0 2019-02-01 01:36:57        201902
# 1 2019-02-01 01:37:23        201902
# 2 2019-02-01 02:34:19        201902

# %%
pd.pivot_table(
    data=join_all,
    index="payment_month",
    columns="item_name",
    values=["quantity", "price"],
    aggfunc="sum",
)
# Out:
#                   price                                         quantity       \
# item_name          PC-A      PC-B      PC-C      PC-D      PC-E     PC-A PC-B
# payment_month
# 201902         24150000  25245000  19800000  31140000  59850000      483  297
# 201903         26000000  25500000  19080000  25740000  64050000      520  300
# 201904         25900000  23460000  21960000  24300000  64890000      518  276
# 201905         24850000  25330000  20520000  25920000  58800000      497  298
# 201906         26000000  23970000  21840000  28800000  63420000      520  282
# 201907         25250000  28220000  19440000  26100000  71610000      505  332
#
#
# item_name     PC-C PC-D PC-E
# payment_month
# 201902         165  173  285
# 201903         159  143  305
# 201904         183  135  309
# 201905         171  144  280
# 201906         182  160  302
# 201907         162  145  341

# %%
monthly_sales = pd.pivot_table(
    data=join_all,
    index="payment_month",
    columns="item_name",
    values="price",
    aggfunc="sum",
)

monthly_sales
# Out:
# item_name          PC-A      PC-B      PC-C      PC-D      PC-E
# payment_month
# 201902         24150000  25245000  19800000  31140000  59850000
# 201903         26000000  25500000  19080000  25740000  64050000
# 201904         25900000  23460000  21960000  24300000  64890000
# 201905         24850000  25330000  20520000  25920000  58800000
# 201906         26000000  23970000  21840000  28800000  63420000
# 201907         25250000  28220000  19440000  26100000  71610000

# %%
monthly_sales.shape
# Out:
# (6, 5)

# %%
import seaborn as sns

sns.lineplot(data=monthly_sales);
